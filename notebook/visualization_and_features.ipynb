# %%
import pandas as pd
from seaborn import pairplot
import matplotlib.pyplot as plt
from statsmodels.graphics.correlation import plot_corr

# %%
#Initializing a new variable for the path
filename = './../data/raw/pctdata.csv'

#Reading the pctdata.csv file
df = pd.read_csv(filename, low_memory=False)

# %%
#pair plot of all
pairplot(df)

# %%
corr = df[:-1].corr()

# %%
# corrolation
corr
# Out:
#               id_plane      id_x      id_y   i_event  i_time_stamp
# id_plane      1.000000  0.007631 -0.009103 -0.001371     -0.001369
# id_x          0.007631  1.000000  0.000412  0.032233      0.032233
# id_y         -0.009103  0.000412  1.000000  0.018257      0.018255
# i_event      -0.001371  0.032233  0.018257  1.000000      1.000000
# i_time_stamp -0.001369  0.032233  0.018255  1.000000      1.000000

# %%
# plotting corrrelation
fig=plot_corr(corr,xnames=corr.columns)

# %%
id_x_arr = df['id_x'].values
type(id_x_arr)
# Out:
# numpy.ndarray

# %%
plt.plot(id_x_arr)
plt.show()

# %%
id_x_series = df['id_x']
type(id_x_series)
# Out:
# pandas.core.series.Series

# %%
plt.plot(id_x_series)
plt.show()

# %%
df.plot()
plt.savefig('df.pdf')
plt.show()

# %%
df.plot()
plt.yscale('log')
plt.savefig('df.png')
plt.show()

# %%
df.plot(x='id_x',y='id_y',kind='scatter')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df.plot(x='i_event',y='i_time_stamp',kind='scatter')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df.plot(x='i_event',y='i_time_stamp',kind='hist')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df.plot(x='id_x',y='id_y',kind='hist')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df[df.columns].plot(kind='box')

# Display the plot
plt.show()

# %%
df[['id_x','id_y']].plot(kind='box')

# Display the plot
plt.show()
